# %% [markdown]
# **Task 3: Exploratory Data Analysis (EDA)**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    "C:/Users/david/Downloads/Data Set For Task/4) house Prediction Data Set.csv",
    delim_whitespace=True,
    header=None
)
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_18364\2109962390.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(

# %%
df.columns = [
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX',
    'RM', 'AGE', 'DIS', 'RAD', 'TAX',
    'PTRATIO', 'B', 'LSTAT', 'PRICE'
]

# %%
df.shape
# Out:
# (506, 14)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  PRICE
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.hist(figsize=(16, 12), bins=20)
plt.suptitle("Histograms of Numerical Features")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
corr_matrix = df.corr()
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)
plt.title("Correlation Matrix")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='RM', y='PRICE', data=df)
plt.title("Number of Rooms vs House Price")
plt.xlabel("Average Number of Rooms (RM)")
plt.ylabel("House Price")
plt.show()

# %%
plt.figure(figsize=(18, 12))

for i, column in enumerate(df.columns, 1):
    plt.subplot(5, 3, i)
    sns.boxplot(y=df[column])
    plt.title(column)
plt.suptitle("BOXPLOTS")
plt.tight_layout()
plt.show()

# %%
sns.pairplot(
    df[['RM', 'LSTAT', 'PTRATIO', 'PRICE']]
)
plt.suptitle("PAIRPLOTS")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(df['PRICE'], kde=True)

plt.title("Distribution of House Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")

plt.show()

# %%
print("\n========== EDA REPORT ==========")

print("""
1. The dataset contains housing-related variables
   used to predict house prices.

2. No major missing values were detected.

3. Correlation analysis shows:
   - RM positively correlates with PRICE.
   - LSTAT negatively correlates with PRICE.

4. Houses with more rooms generally have higher prices.

5. Some features contain outliers,
   especially CRIM and TAX.

6. The target variable PRICE appears
   reasonably distributed.

7. The dataset is suitable for predictive
   modeling and regression analysis.
""")
# Out:
# ========== EDA REPORT ==========
#
# 1. The dataset contains housing-related variables
#    used to predict house prices.
#
# 2. No major missing values were detected.
#
# 3. Correlation analysis shows:
#    - RM positively correlates with PRICE.
#    - LSTAT negatively correlates with PRICE.
#
# 4. Houses with more rooms generally have higher prices.
#
# 5. Some features contain outliers,
#    especially CRIM and TAX.
#
# 6. The target variable PRICE appears
#    reasonably distributed.
#
# 7. The dataset is suitable for predictive
#    modeling and regression analysis.
